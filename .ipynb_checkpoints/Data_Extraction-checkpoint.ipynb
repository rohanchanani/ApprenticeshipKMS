# %%
import docx
import docx2txt
import sqlalchemy

# %%
# !pip install psycopg2
# Out:
# ...
#   Using cached psycopg2-2.9.3-cp39-cp39-win_amd64.whl (1.2 MB)
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.1 is available.
# You should consider upgrading via the 'C:\Users\Rohan Chanani\Downloads\ApprenticeshipKMS\apprenticeship\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
engine = sqlalchemy.create_engine('postgresql://apprenticeship:test123@localhost:5432/kmsforms')

# %%
# %reload_ext sql
# %sql $engine.url

# %%
text = docx2txt.process("Completed Anonym KMS Assessment Discussion Framework R03.3-.docx")
all_lines = [line.strip() for line in text.split("\n") if line != ""]
all_lines
# Out:
# ['Page | 2',
#  'Architecture',
#  'Page | 2',
#  'Development – Section 3',
#  'Page | 2',
#  'Product and Organization – Section 1',
#  'Page | 2',
#  'Architecture – Section 2',
#  'Page | 2',
#  'Testing – Section 4',
#  'Page | 2',
#  'DevOps – Section 5',
#  'Page | 2',
#  'Security – Section 6',
#  'Page | 2',
#  'Customer – Section 7',
#  'KMS Technology',
#  'Technology Assessment',
#  'Discussion Framework',
#  'Document Version R03.3',
#  '3/1/2022',
#  'Technology Assessment of',
#  'A SaaS Co.',
#  'Contents',
#  'Product and Organization Overview\t1',
#  'Architecture and Hosting\t3',
#  'Development Practices and Tooling\t5',
#  'Test Practices and Tooling\t7',
#  'DevOps\t9',
#  'Security\t10',
#  'Customer Support/Customer Success\t11',
#  'KMS Technology Assessment Team:',
#  'Jeff Scott, John Jeske',
#  'Product and Organization Overview',
# ...

# %%
doc = docx.Document("Completed Anonym KMS Assessment Discussion Framework R03.3-.docx")
questions = [paragraph.text.strip() for paragraph in doc.paragraphs if paragraph.text != "" and paragraph.style.name in ["Heading 2", "Heading 3"]]
sections = [paragraph.text.strip() for paragraph in doc.paragraphs if paragraph.text != "" and paragraph.style.name == "Heading 1"]

# %%
print(f"Company: {all_questions[0]['company']}")
print(f"Version: {all_questions[0]['version']}")
for question in all_questions:
    print(f"Section: {question['section']}")
    print(str(question["number"]) + ". " + question["question"])    
    print(question["answer"])
    print("_________________________________________________")
# Out:
# Company: A SaaS Co.
# Version: R03.3
# Section: Product and Organization Overview
# 1. Describe your Product Management Organization. [Please provide any associated documentation, i.e., Organization Chart, Roles, Responsibilities & Experience.]
# Product management has always ultimately been led by the chief officers. They bring in market feedback and coordinate with sales and marketing. The director of product" has been managing IT support and product engineering. the director of product coordinates the collection of feedback from existing customer through the it/product support infastructure. We've never had anyone solely dedicated to true product management. Just this year we've hired a product specialist and established an IT manager and support team in an effort to allow for some time dedicated toward product management. We have two software development managers, two internal QA analysts, and 4 remote development teams at an average size of 3 developers.
# ...

# %%
def read_questions(company, version, current_section, i, question_list):
    question_number = 1
    while i < len(all_lines):
        current_question = all_lines[i]
        try:
            next_ten_questions = questions[questions.index(current_question) + 1: questions.index(current_question) + 11]
        except:
            i += 1
            continue
        current_answer = all_lines[i+1]
        i += 2
        while i < len(all_lines):
            if all_lines[i] in next_ten_questions:
                break
            if all_lines[i] == sections[min(sections.index(current_section) + 1, len(sections) - 1)]:
                current_section = all_lines[i]
                i += 1
                break
            current_answer += "\n" + all_lines[i]
            i += 1
        upload_question_to_database(question_list, current_question, current_answer, current_section, company_name, document_version, question_number)
        question_number += 1

# %%
i = 0
version_not_found = True
current_section = ""
question_number = 1
questions_started = False
all_questions = []
while not questions_started:
    if all_lines[i] == "Technology Assessment of":
        company_name = all_lines[i+1]
        i += 2
    elif "Document Version" in all_lines[i] and version_not_found:
        document_version = all_lines[i].split(" ")[-1]
        version_not_found = False
        i += 1
    elif all_lines[i] in sections:
        current_section = all_lines[i]
        i += 1
        questions_started = True
    else:
        i += 1

read_questions(company_name, document_version, current_section, i, all_questions)

# %%
found_questions = [question["question"] for question in all_questions]
[question for question in questions if question not in found_questions]
# Out:
# ['What are stability and availability requirements?',
#  'Is there a specific delivery or technology mindset you expect the testing team to adopt?',
#  'Do you have a designated individual or group responsible for cyber-security?',
#  'Are Penetration Tests performed?',
#  'Are vulnerability scans conducted?',
#  'Has the organization experienced a cybersecurity breach in the past five years?',
#  'How do you manage the use of open-source software?',
#  'Do you have a strategy or process around software selection, approval, and inventory?',
#  'What customer support tools are in place?']

# %%
def upload_question_to_database(question_list, question, answer, section, company, version, number):
    container = {}
    container["question"] = question
    container["answer"] = answer
    container["section"] = section
    container["company"] = company
    container["version"] = version
    container["number"] = number
    question_list.append(container)

# %%
len(all_questions)
# Out:
# 155
